# %%
# !pip uninstall -y bitsandbytes
# !pip install -U bitsandbytes accelerate peft transformers
# !pip install transformers
# !pip install torch torchvision torchaudio
# !pip install datasets
# !pip install accelerate

# !pip install rouge-score
# !pip install nltk
# !pip install evaluate
# !pip install huggingface_hub
# !pip install -U transformers
# install once at the top
# !pip install -U bitsandbytes accelerate
# Out:
# WARNING: Skipping bitsandbytes as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 78.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.1
#     Uninstalling transformers-4.56.1:
#       Successfully uninstalled transformers-4.56.1
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=f9451727d1424b58c75f53e3958423fca2164f3db1f8782cae46f094c1a18e63
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
from huggingface_hub import login

# Log in to Hugging Face
login(token="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")

# Use the translation pipeline for T5 models
pipe = pipeline("summarization", model="csebuetnlp/banglat5_nmt_en_bn")

# Example text to translate
text = "This is not a test sentence to translate into Bengali."

# Perform translation
translated_text = pipe(text)
print(translated_text)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Device set to use cuda:0
# Your max_length is set to 128, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
# [{'summary_text': 'এটি বাংলা ভাষায় অনুবাদ করার জন্য কোন পরীক্ষামূলক বাক্য নয়।'}]

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import pipeline

# Load tokenizer and model for Bangla summarization (replace with a summarization model)
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/banglat5_nmt_en_bn")  # Replace with the summarization model if available
tokenizer.padding_side = "left"

model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/banglat5_nmt_en_bn")  # Replace with the summarization model if available

# Initialize the pipeline for summarization
summarizer = pipeline("summarization", model=model, tokenizer=tokenizer)

# Example text in Bangla to summarize
text = """আপনি যদি বাংলাদেশের সাম্প্রতিক প্রেক্ষাপটের কথা বলুন, তবে সেখানে শহরের দ্রুত উন্নয়ন, নতুন প্রযুক্তি ও আধুনিক জীবনযাত্রার সাথে সাথে দেশের সমাজে কিছু চ্যালেঞ্জও এসেছে। এই চ্যালেঞ্জগুলোর মধ্যে উল্লেখযোগ্য হলো, শিক্ষা, স্বাস্থ্যসেবা, এবং কর্মসংস্থান সংক্রান্ত সমস্যা।"""

# Get the summary
summary = summarizer(text, max_length=50, min_length=30, do_sample=False)

# Print the summary
print("Summary:", summary[0]['summary_text'])
# Out:
# Device set to use cuda:0
# Your max_length is set to 50, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Summary: আপনি যদি বাংলাদেশের সাম্প্রতিক সময়ের কথা বলেন, তবে সেখানে শহরের দ্রুত উন্নয়ন, নতুন প্রযুক্তি ও আধুনিক জীবনযাত্রার সঙ্গে সঙ্গে দেশের সমাজে কিছু চ্যালেঞ্জও এসেছে, যেমন- শিক্ষা, স্বাস্থ্য ও কর্মসংস্থান।

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/banglat5_nmt_en_bn")
# Set padding side for T5 models (this is optional but recommended for decoder models like mT5)
tokenizer.padding_side = "left"

# Load the T5 model for sequence-to-sequence tasks
model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/banglat5_nmt_en_bn")

# Now the model is ready to use for translation tasks
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login
login(new_session=False)


##KOTHAR ID TOKEN OF HUGGING FACE
import os
os.environ['HF_TOKEN'] = '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'

# %%
from datasets import load_dataset
from evaluate import load  # For loading metrics like ROUGE, BLEU
from rouge_score import rouge_scorer
import nltk
nltk.download('punkt')
from nltk.translate.bleu_score import sentence_bleu
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Set the model to use GPU
model.to("cuda")
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
# ...

# %%
import torch
# Load the tokenizer for your model


# Ensure the padding token is defined
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': '[PAD]'})



# Break long texts into overlapping chunks

MAX_LEN = 256     # start here; you can try 384 later
OVERLAP = 64

def sliding_window_tokenize(text, tokenizer, max_length=MAX_LEN, overlap=OVERLAP):
    # tokenize to *ids* directly and slice ids; this avoids token->string->token roundtrips
    ids = tokenizer.encode(text, add_special_tokens=False)
    chunks = []
    step = max_length - overlap
    for i in range(0, len(ids), step):
        chunks.append(ids[i:i+max_length])
    return chunks


# Generate summaries for long texts (handles multiple chunks)
def generate_summary(model, tokenizer, input_text, max_length=100, overlap=10):
    chunks = sliding_window_tokenize(input_text, tokenizer, max_length=max_length, overlap=overlap)
    generated_summaries = []

    # Generate summary for each chunk
    for chunk in chunks:
        # Convert tokenized chunks back into text
        chunk_text = tokenizer.convert_tokens_to_string(chunk)

        # Tokenize the chunk text and move to GPU
        inputs = tokenizer(chunk_text, return_tensors="pt", padding="max_length", truncation=True, max_length= MAX_LEN).to("cuda")

        with torch.no_grad():
            outputs = model.generate(inputs['input_ids'], max_new_tokens=200)

        summary_chunk = tokenizer.decode(outputs[0], skip_special_tokens=True)
        generated_summaries.append(summary_chunk)

    # Combine summaries from all chunks into the final summary
    final_summary = " ".join(generated_summaries)
    return final_summary

# Correct Tokenization Function
def tokenize_function(examples):
    input_ids_list = []
    attention_masks_list = []

    for article in examples["article"]:
        # break a long article into <=MAX_LEN chunks of token IDs
        chunks = sliding_window_tokenize(article, tokenizer, max_length=MAX_LEN, overlap=OVERLAP)
        for ids in chunks:
            # pad to MAX_LEN using the tokenizer’s pad_token_id
            attn = [1]*len(ids)
            if len(ids) < MAX_LEN:
                pad_len = MAX_LEN - len(ids)
                ids  = ids + [tokenizer.pad_token_id]*pad_len
                attn = attn + [0]*pad_len

            input_ids_list.append(ids)
            attention_masks_list.append(attn)

    return {"input_ids": input_ids_list, "attention_mask": attention_masks_list}


# Example to load your dataset (adjust paths accordingly)
from datasets import load_dataset
from google.colab import drive
drive.mount('/content/drive')

dataset = load_dataset('json', data_files={"train": "/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_train.jsonl",
                                            "validation": "/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_val.jsonl",
                                            "test": "/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_test.jsonl"})

# Tokenize the dataset using the tokenize function defined earlier
train_dataset = dataset["train"].map(tokenize_function, batched=True, remove_columns=dataset["train"].column_names)
valid_dataset = dataset["validation"].map(tokenize_function, batched=True, remove_columns=dataset["validation"].column_names)
test_dataset  = dataset["test"].map(tokenize_function, batched=True, remove_columns=dataset["test"].column_names)

# make them PyTorch-ready *after* map
train_dataset.set_format(type="torch", columns=["input_ids","attention_mask"])
valid_dataset.set_format(type="torch", columns=["input_ids","attention_mask"])
test_dataset.set_format(type="torch",  columns=["input_ids","attention_mask"])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/18291 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (888 > 512). Running this sequence through the model will result in indexing errors
# ...
# Map:   0%|          | 0/2287 [00:00<?, ? examples/s]

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# (Optional, but recommended for k-bit fine-tuning)
model = prepare_model_for_kbit_training(model)

# LoRA config — updated for T5 model with the correct layer names
lora_config = LoraConfig(
    r=8,                      # try 8; increase to 16 later if VRAM allows
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="SEQ_2_SEQ_LM",     # Correct task_type for T5 (sequence-to-sequence)
    target_modules=[
        # Encoder attention layers
        "encoder.block.*.layer.*.SelfAttention.q",
        "encoder.block.*.layer.*.SelfAttention.k",
        "encoder.block.*.layer.*.SelfAttention.v",
        "encoder.block.*.layer.*.SelfAttention.o",

        # Encoder feed-forward layers
        "encoder.block.*.layer.*.DenseReluDense.wi_0",
        "encoder.block.*.layer.*.DenseReluDense.wi_1",
        "encoder.block.*.layer.*.DenseReluDense.wo",

        # Decoder attention layers
        "decoder.block.*.layer.*.SelfAttention.q",
        "decoder.block.*.layer.*.SelfAttention.k",
        "decoder.block.*.layer.*.SelfAttention.v",
        "decoder.block.*.layer.*.SelfAttention.o",

        # Decoder feed-forward layers
        "decoder.block.*.layer.*.DenseReluDense.wi_0",
        "decoder.block.*.layer.*.DenseReluDense.wi_1",
        "decoder.block.*.layer.*.DenseReluDense.wo"
    ]
)

# Apply the LoRA configuration to the model
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()  # sanity check to confirm trainable parameters
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1713085120.py in <cell line: 0>()
#      37
#      38 # Apply the LoRA configuration to the model
# ---> 39 model = get_peft_model(model, lora_config)
#      40 model.print_trainable_parameters()  # sanity check to confirm trainable parameters
#
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py in get_peft_model(model, peft_config, adapter_name, mixed, autocast_adapter_dtype, revision, low_cpu_mem_usage)
#     123     if peft_config.is_prompt_learning:
#     124         peft_config = _prepare_prompt_learning_config(peft_config, model_config)
# --> 125     return MODEL_TYPE_TO_PEFT_MODEL_MAPPING[peft_config.task_type](
#     126         model,
#     127         peft_config,
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in __init__(self, model, peft_config, adapter_name, **kwargs)
# ...

# %%
from transformers import Trainer, TrainingArguments
import torch

# Ensure model is in training mode
model.train()

# Training Arguments with the desired configurations
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,                    # Save to /content/llama3_prothomalo_checkpoints
    num_train_epochs=1,
    per_device_train_batch_size=16,           # keep small batch size to save VRAM
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=16,           # effective batch size = 32
    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_ratio=0.03,
    logging_steps=10,
    save_strategy="steps",                    # save checkpoint after each `save_steps`
    save_steps=70,                           # save every 250 steps
    save_total_limit=2,                       # keep only the last 2 checkpoints
    fp16=True,                                # mixed precision for memory efficiency
    optim="adamw_bnb_8bit",
    report_to=[]
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,  # Ensure you are passing the correct training dataset
    eval_dataset=valid_dataset,   # Ensure you are passing the correct evaluation dataset
    data_collator=data_collator,
    callbacks=[AutoDownloadCallback(save_dir=OUTPUT_DIR, download_every=70)]  # Save and download after 250 steps
)

# Check for existing checkpoint, if none, start fresh
last_ckpt = get_last_checkpoint(OUTPUT_DIR)
if last_ckpt is not None:
    print(f"Resuming from checkpoint: {last_ckpt}")
    train_result = trainer.train(resume_from_checkpoint=last_ckpt)
else:
    print("No checkpoint found, starting fresh.")
    train_result = trainer.train()

# Evaluate the model after training
print(trainer.evaluate(eval_dataset=valid_dataset))

# Clear CUDA memory after evaluation
gc.collect()
torch.cuda.empty_cache()

# Example generation (Generate text from the model)
example = valid_dataset[0]
inputs = {
    "input_ids": example["input_ids"].unsqueeze(0),  # Add batch dimension
    "attention_mask": example["attention_mask"].unsqueeze(0)  # Add batch dimension
}

# Ensure the inputs are on the correct device (GPU/CPU)
inputs["input_ids"] = inputs["input_ids"].to(model.device)
inputs["attention_mask"] = inputs["attention_mask"].to(model.device)

# Generate output
with torch.no_grad():
    gen = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=200,
        do_sample=False
    )

# Decode and print the generated text
print(tokenizer.decode(gen[0], skip_special_tokens=True))
# Out:
# No checkpoint found, starting fresh.
# /usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1190553766.py in <cell line: 0>()
#      41 else:
#      42     print("No checkpoint found, starting fresh.")
# ---> 43     train_result = trainer.train()
#      44
#      45 # Evaluate the model after training
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326                 hf_hub_utils.enable_progress_bars()
#    2327         else:
# -> 2328             return inner_training_loop(
#    2329                 args=args,
#    2330                 resume_from_checkpoint=resume_from_checkpoint,
#
# ...

# %%
trainer.save_model("/content/llama3_1b_trained_on_Prothomalo")
tokenizer.save_pretrained("/content/llama3_1b_trained_on_Prothomalo")

# !zip -r llama3_1b_trained_on_Prothomalo.zip /content/llama3_1b_trained_on_Prothomalo
from google.colab import files
files.download("llama3_1b_trained_on_Prothomalo.zip")

# %%
model.save_pretrained("/content/llama3_1b_lora")
tokenizer.save_pretrained("/content/llama3_1b_lora")

from peft import PeftModel
from transformers import AutoModelForCausalLM

base = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B", device_map="auto")
model = PeftModel.from_pretrained(base, "/content/llama3_1b_lora")

# %%
# !pip install transformers evaluate bert-score tqdm
# !pip install rouge_score sacrebleu bert-score

# %%
import json
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from tqdm.auto import tqdm

# Path to your JSONL validation dataset
dataset_path = '/content/bwsd_prothomalo_clean_val.jsonl'

# Load the dataset
def load_dataset(file_path):
    dataset = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            dataset.append(obj)
    return dataset

data = load_dataset(dataset_path)

# Limit to the first 50 entries
# subset_size = 50
# data = data[:subset_size]

articles   = [d['article'] for d in data]
references = [d['summary'] for d in data]

# Move model to GPU/CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

# Generation parameters
batch_size        = 20
max_input_length  = 512      # input truncation length
max_new_tokens    = 128      # how many tokens to generate in the summary
num_beams         = 4



# Generate summaries and store in `predictions`
predictions = []
for i in tqdm(range(0, len(articles), batch_size), desc="Generating"):
    batch = articles[i:i+batch_size]
    inputs = tokenizer(
        batch,
        max_length=max_input_length,
        truncation=True,
        padding=True,
        return_tensors='pt'
    ).to(device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,  # specify new tokens to generate
            num_beams=num_beams,
            no_repeat_ngram_size=3,
            early_stopping=True,
            do_sample=False
        )

    decoded = tokenizer.batch_decode(
        outputs,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=True
    )
    predictions.extend([s.strip() for s in decoded])

print(f"Generated {len(predictions)} summaries.")
# At this point `predictions` and `references` can be used for evaluation.

# %%
import numpy as np
import evaluate

# Install missing dependencies if needed
# !pip install rouge_score sacrebleu bert-score evaluate

# Compute ROUGE (1/2/L) and BLEU
rouge = evaluate.load('rouge')
rouge_scores = rouge.compute(
    predictions=predictions,
    references=references,
    rouge_types=['rouge1', 'rouge2', 'rougeL'],
    use_aggregator=True
)

bleu = evaluate.load('bleu')
bleu_result = bleu.compute(
    predictions=predictions,
    references=[[ref] for ref in references]
)

# Compute BERTScore WITHOUT baseline rescaling to avoid the error
bertscore = evaluate.load('bertscore')
bs_result = bertscore.compute(
    predictions=predictions,
    references=references,
    lang='bn',
    rescale_with_baseline=False  # disable baseline rescaling:contentReference[oaicite:3]{index=3}
)
bertscore_f1        = float(np.mean(bs_result['f1']))
bertscore_precision = float(np.mean(bs_result['precision']))
bertscore_recall    = float(np.mean(bs_result['recall']))

# Save results to metrics.txt
with open('Llama3-prothomalo-metrics.txt', 'w', encoding='utf-8') as f:
    f.write(f"ROUGE-1: {rouge_scores['rouge1']:.4f}\n")
    f.write(f"ROUGE-2: {rouge_scores['rouge2']:.4f}\n")
    f.write(f"ROUGE-L: {rouge_scores['rougeL']:.4f}\n")
    f.write(f"BLEU:    {bleu_result['bleu']:.4f}\n")
    f.write(f"BERTScore F1: {bertscore_f1:.4f}\n")
    f.write(f"BERTScore Precision: {bertscore_precision:.4f}\n")
    f.write(f"BERTScore Recall: {bertscore_recall:.4f}\n")


from google.colab import files
files.download("Llama3-prothomalo-metrics.txt")
print("Metrics saved to Llama3-prothomalo-metrics.txt")

# %%
# Install necessary packages
# !pip install transformers datasets huggingface_hub evaluate rouge_score sacrebleu bert-score

# Import required libraries
import json
import numpy as np
import evaluate
from transformers import pipeline, T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments
from datasets import Dataset
from huggingface_hub import login

# Log in to Hugging Face
login(token="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")

# Define dataset paths (update with your actual paths)
train_path = '/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_train.jsonl'
val_path = '/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_val.jsonl'
test_path = '/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_test.jsonl'

# Function to load dataset from JSONL file
def load_dataset(file_path):
    dataset = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            dataset.append(obj)
    return dataset

# Load the datasets
train_data = load_dataset(train_path)
val_data = load_dataset(val_path)
test_data = load_dataset(test_path)

# Example: Replace these with your model's predictions and the corresponding reference texts
train_articles = [d['article'] for d in train_data]
train_summaries = [d['summary'] for d in train_data]
val_articles = [d['article'] for d in val_data]
val_summaries = [d['summary'] for d in val_data]
test_articles = [d['article'] for d in test_data]
test_summaries = [d['summary'] for d in test_data]

# Load the tokenizer
tokenizer = T5Tokenizer.from_pretrained("google/mt5-small")  # Change to Bangla T5 if available

# Preprocessing function
def preprocess_function(examples):
    inputs = examples['article']
    targets = examples['summary']
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Prepare datasets
train_dataset = Dataset.from_dict({"article": train_articles, "summary": train_summaries})
val_dataset = Dataset.from_dict({"article": val_articles, "summary": val_summaries})
test_dataset = Dataset.from_dict({"article": test_articles, "summary": test_summaries})

# Apply preprocessing to all datasets
train_dataset = train_dataset.map(preprocess_function, batched=True)
val_dataset = val_dataset.map(preprocess_function, batched=True)
test_dataset = test_dataset.map(preprocess_function, batched=True)

# Load the model
model = T5ForConditionalGeneration.from_pretrained("google/mt5-small")  # Change to Bangla T5 if available

# Training Arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch",  # Evaluate at the end of each epoch
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
)

# Train the model
trainer.train()

# Evaluate the model on the test set
results = trainer.evaluate(test_dataset)
print("Evaluation results:", results)

# Example of using the summarization pipeline
summarization_pipe = pipeline("summarization", model=model, tokenizer=tokenizer)

# Example text for summarization (you can replace this with an article from the dataset)
article_text = "বাংলাদেশে জলবায়ু পরিবর্তনজনিত কারণে সমুদ্রপৃষ্ঠের উচ্চতা বৃদ্ধি, ঘূর্ণিঝড়, বন্যা, নদীভাঙ্গনসহ বিভিন্ন প্রাকৃতিক দুর্যোগের শিকার হচ্ছেন মানুষ। বিশেষ করে দেশের দক্ষিণাঞ্চলের মানুষের জীবনযাত্রা বিপন্ন। এসব প্রাকৃতিক দুর্যোগে প্রাণহানির পরিমাণও আশঙ্কাজনক। বাংলাদেশে এখনকার মতো যদি জলবায়ু পরিবর্তনের কারণে প্রাকৃতিক বিপর্যয়গুলি আরও বাড়তে থাকে তবে মানুষের জন্য আরো কঠিন হয়ে পড়বে জীবনযাপন।"

# Perform summarization
summary = summarization_pipe(article_text)
print("Summarized Text:", summary)

# Compute ROUGE (1/2/L) and BLEU
rouge = evaluate.load('rouge')
rouge_scores = rouge.compute(
    predictions=summary,
    references=[article_text],
    rouge_types=['rouge1', 'rouge2', 'rougeL'],
    use_aggregator=True
)

bleu = evaluate.load('bleu')
bleu_result = bleu.compute(
    predictions=summary,
    references=[[article_text]]  # BLEU requires references to be in a list of lists format
)

# Compute BERTScore WITHOUT baseline rescaling to avoid the error
bertscore = evaluate.load('bertscore')
bs_result = bertscore.compute(
    predictions=summary,
    references=[article_text],
    lang='bn',  # Adjust the language to 'bn' for Bangla
    rescale_with_baseline=False  # Disable baseline rescaling to avoid errors
)

# Extract BERTScore metrics
bertscore_f1        = float(np.mean(bs_result['f1']))
bertscore_precision = float(np.mean(bs_result['precision']))
bertscore_recall    = float(np.mean(bs_result['recall']))

# Save results to metrics.txt
with open('Llama3-prothomalo-metrics.txt', 'w', encoding='utf-8') as f:
    f.write(f"ROUGE-1: {rouge_scores['rouge1']:.4f}\n")
    f.write(f"ROUGE-2: {rouge_scores['rouge2']:.4f}\n")
    f.write(f"ROUGE-L: {rouge_scores['rougeL']:.4f}\n")
    f.write(f"BLEU:    {bleu_result['bleu']:.4f}\n")
    f.write(f"BERTScore F1: {bertscore_f1:.4f}\n")
    f.write(f"BERTScore Precision: {bertscore_precision:.4f}\n")
    f.write(f"BERTScore Recall: {bertscore_recall:.4f}\n")

# Save the metrics file and download it
from google.colab import files
files.download("Llama3-prothomalo-metrics.txt")
print("Metrics saved to Llama3-prothomalo-metrics.txt")
# Out:
# ...
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# /tmp/ipython-input-1992006470.py in <cell line: 0>()
#      31
#      32 # Load the datasets
# ---> 33 train_data = load_dataset(train_path)
#      34 val_data = load_dataset(val_path)
#      35 test_data = load_dataset(test_path)
#
# /tmp/ipython-input-1992006470.py in load_dataset(file_path)
#      21 def load_dataset(file_path):
#      22     dataset = []
# ---> 23     with open(file_path, 'r', encoding='utf-8') as f:
#      24         for line in f:
#      25             line = line.strip()
#
# ConnectionAbortedError: [Errno 103] Software caused connection abort: '/content/drive/MyDrive/thesis1/bwsd_prothomalo_clean_train.jsonl'
